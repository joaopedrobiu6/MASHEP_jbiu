# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from sklearn.metrics import roc_curve, roc_auc_score
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras import Input
from tensorflow.keras.optimizers import Adam
tf.random.set_seed(2)

import pyhf

# %%
dataframe = pd.read_csv('dataframe.csv')

# %%
dataframe['train_weight'] = 1.
dataframe.loc[dataframe.query('label==1').index,'train_weight'] = (dataframe.loc[dataframe.query('label==1').index,'scaleweight']) / dataframe.loc[dataframe.query('label==1').index,'scaleweight'].sum()
dataframe.loc[dataframe.query('label==0').index,'train_weight'] = dataframe.loc[dataframe.query('label==0').index,'scaleweight'] / dataframe.loc[dataframe.query('label==0').index,'scaleweight'].sum()

sum_w_sig = dataframe.query('label==0')['train_weight'].sum()
sum_w_bkg = dataframe.query('label==1')['train_weight'].sum()
print(f'Sum of weights for training Signal {sum_w_sig:.3} and Background {sum_w_bkg:.3}')
# Out:
# Sum of weights for training Signal 1.0 and Background 1.0

# %%
train_features = ['etmiss', 'mtw', 'leadleptPt', 'leadleptEta',
       'leadleptE', 'leadleptPhi', 'Q_leadlep', 'leadleptID', 'n_TopLRjets',
       'leadTopLRjet_pt', 'leadTopLRjet_eta', 'leadTopLRjet_phi',
       'leadTopLRjet_m', 'leadTopLRjet_Tau32', 'n_jets', 'leadjet_pt',
       'leadjet_eta', 'n_bjets', 'leadbjet_pt', 'leadbjet_eta', 'ttbarMLR']

weights = ["scaleweight", "train_weight"]

# %%
x_train, x_val, y_train, y_val, w_train_full, w_val_full = train_test_split(dataframe[train_features].values, dataframe['label'].values, dataframe[weights].values, train_size = 1/3, random_state = 9)
x_val, x_test, y_val, y_test, w_val_full, w_test_full = train_test_split(x_val, y_val, w_val_full, test_size=1/2, random_state = 9)


scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %%
def weight_separation(w):
    scaleweights = w[:, 0]
    train = w[:, 1]
    return scaleweights, train

w_train_scale, w_train = weight_separation(w_train_full)
w_val_scale, w_val = weight_separation(w_val_full)
w_test_scale, w_test = weight_separation(w_test_full)

# %%
# your answer
model = Sequential([Input(shape=(x_train.shape[1],))])

# Input and Hidden layers
model.add(Dense(80, activation='softsign'))
model.add(Dense(90, activation='softsign'))
model.add(Dense(100, activation='relu'))
model.add(Dense(90, activation='softsign'))
model.add(Dense(80, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=1e-3), weighted_metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 80)             │         1,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 90)             │         7,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │         9,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 90)             │         9,090 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 80)             │         7,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            81 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,601 (135.16 KB)
#  Trainable params: 34,601 (135.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, sample_weight=w_train, validation_data=(x_val, y_val, w_val), epochs=200, batch_size=1024, callbacks=[EarlyStopping(patience=2)])
# Out:
# Epoch 1/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5247 - loss: 5.5220e-06 - val_accuracy: 0.5495 - val_loss: 5.4365e-06
# Epoch 2/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5621 - loss: 5.4905e-06 - val_accuracy: 0.5702 - val_loss: 5.3994e-06
# Epoch 3/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5832 - loss: 5.4526e-06 - val_accuracy: 0.5808 - val_loss: 5.3592e-06
# Epoch 4/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5921 - loss: 5.4118e-06 - val_accuracy: 0.5876 - val_loss: 5.3177e-06
# Epoch 5/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5994 - loss: 5.3712e-06 - val_accuracy: 0.5946 - val_loss: 5.2770e-06
# Epoch 6/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6006 - loss: 5.3306e-06 - val_accuracy: 0.6028 - val_loss: 5.2353e-06
# Epoch 7/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6098 - loss: 5.2861e-06 - val_accuracy: 0.6139 - val_loss: 5.1868e-06
# Epoch 8/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6177 - loss: 5.2317e-06 - val_accuracy: 0.6244 - val_loss: 5.1289e-06
# Epoch 9/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6281 - loss: 5.1652e-06 - val_accuracy: 0.6353 - val_loss: 5.0610e-06
# Epoch 10/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6424 - loss: 5.0863e-06 - val_accuracy: 0.6457 - val_loss: 4.9916e-06
# Epoch 11/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6531 - loss: 5.0061e-06 - val_accuracy: 0.6546 - val_loss: 4.9297e-06
# Epoch 12/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6621 - loss: 4.9336e-06 - val_accuracy: 0.6580 - val_loss: 4.8804e-06
# Epoch 13/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6732 - loss: 4.8714e-06 - val_accuracy: 0.6642 - val_loss: 4.8427e-06
# Epoch 14/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6804 - loss: 4.8187e-06 - val_accuracy: 0.6657 - val_loss: 4.8124e-06
# Epoch 15/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6842 - loss: 4.7713e-06 - val_accuracy: 0.6681 - val_loss: 4.7853e-06
# Epoch 16/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6895 - loss: 4.7267e-06 - val_accuracy: 0.6703 - val_loss: 4.7630e-06
# Epoch 17/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6945 - loss: 4.6858e-06 - val_accuracy: 0.6735 - val_loss: 4.7434e-06
# Epoch 18/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6967 - loss: 4.6458e-06 - val_accuracy: 0.6754 - val_loss: 4.7259e-06
# Epoch 19/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7021 - loss: 4.6092e-06 - val_accuracy: 0.6773 - val_loss: 4.7112e-06
# Epoch 20/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7018 - loss: 4.5747e-06 - val_accuracy: 0.6798 - val_loss: 4.6974e-06
# Epoch 21/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7048 - loss: 4.5415e-06 - val_accuracy: 0.6836 - val_loss: 4.6851e-06
# Epoch 22/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7088 - loss: 4.5100e-06 - val_accuracy: 0.6851 - val_loss: 4.6743e-06
# Epoch 23/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7119 - loss: 4.4808e-06 - val_accuracy: 0.6871 - val_loss: 4.6643e-06
# Epoch 24/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7159 - loss: 4.4509e-06 - val_accuracy: 0.6884 - val_loss: 4.6574e-06
# Epoch 25/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7161 - loss: 4.4236e-06 - val_accuracy: 0.6898 - val_loss: 4.6505e-06
# Epoch 26/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7182 - loss: 4.3974e-06 - val_accuracy: 0.6901 - val_loss: 4.6448e-06
# Epoch 27/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7192 - loss: 4.3718e-06 - val_accuracy: 0.6902 - val_loss: 4.6424e-06
# Epoch 28/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7226 - loss: 4.3461e-06 - val_accuracy: 0.6898 - val_loss: 4.6406e-06
# Epoch 29/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7259 - loss: 4.3214e-06 - val_accuracy: 0.6896 - val_loss: 4.6405e-06
# Epoch 30/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7261 - loss: 4.2954e-06 - val_accuracy: 0.6890 - val_loss: 4.6430e-06
# Epoch 31/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7294 - loss: 4.2693e-06 - val_accuracy: 0.6911 - val_loss: 4.6424e-06

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)
y_test_pred = model.predict(x_test)
# Out:
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 213us/step
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 219us/step
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 229us/step

# %%
bin = plt.hist(y_test_pred[y_test==0], bins=100, density=True, histtype='step', color='blue', label='bkg test')
plt.hist(y_test_pred[y_test==1], bins=bin[1], density=True, histtype='step', color='red', label='sig test')

plt.xlabel('NN output')
plt.ylabel('Density')
plt.legend()

# %%
# your answer
bins = plt.hist(y_train_pred[y_train==1], bins=100, density=True, histtype='step', color='blue', label='sig train')
plt.hist(y_val_pred[y_val==1], bins=bins[1], density=True, histtype='step', color='red', label='sig val')
bins = plt.hist(y_train_pred[y_train==0], bins=bins[1], density=True, histtype='step', color='green', label='bkg train')
plt.hist(y_val_pred[y_val==0], bins=bins[1], density=True, histtype='step', color='orange', label='bkg val')

plt.xlabel('NN output')
plt.legend()
plt.show()

# %%
# RPC curve
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred)
auc = roc_auc_score(y_val, y_val_pred)
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='black')
plt.title('ROC curve')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend()
plt.show()

# %%
# join the y predictions and scaleweights into a dataframe with two columns
def join_y_w(y, w):
    df = pd.DataFrame({'y_pred': y, 'scaleweights': w})
    return df

df_train = join_y_w(y_train_pred[:, 0], w_train_scale[:])
df_val = join_y_w(y_val_pred[:, 0], w_val_scale[:])
df_test = join_y_w(y_test_pred[:, 0], w_test_scale[:]*3)

# %%
data = pd.read_csv('Output_ZPrimeBoostedAnalysis/data.csv', delimiter= " ")
data
# Out:
#          etmiss       mtw  leadleptPt  leadleptEta  leadleptE  leadleptPhi  \
# 0      140.8590  112.6010    173.3020    -0.719597   220.1410    -0.629445
# 1      101.1240   12.9607     84.2450     0.521832    95.9780     1.694020
# 2       93.8502  145.9590     69.5917    -0.571767    81.2804     2.401100
# 3       79.1584   78.5076     39.4455     0.320825    41.4930     1.189650
# 4       49.9677  119.0770     78.1793    -1.261530   149.0890    -0.060379
# ...         ...       ...         ...          ...        ...          ...
# 13983   51.2650   36.3069     32.4356    -1.826030   103.3120     2.875370
# 13984  177.2230   98.1917    226.8500     0.625051   272.6260     2.951550
# 13985  379.7260   76.7778     38.0448     0.559037    44.1463    -2.853520
# 13986   76.5990   32.0798     68.3700    -0.439462    75.0790    -0.758893
# 13987  171.2450   48.1760     46.2895     1.833340   148.4640    -0.367425
#
#        Q_leadlep  leadleptID  n_TopLRjets  leadTopLRjet_pt  ...  n_bjets  \
# 0              1          11            1          303.808  ...        2
# 1              1          13            1          319.519  ...        1
# 2              1          11            1          379.502  ...        1
# 3             -1          11            1          364.358  ...        2
# 4              1          11            1          381.640  ...        4
# ...          ...         ...          ...              ...  ...      ...
# 13983          1          11            1          313.153  ...        1
# 13984         -1          13            1          403.237  ...        1
# 13985          1          13            1          618.111  ...        2
# 13986          1          11            1          336.483  ...        1
# 13987         -1          13            1          378.259  ...        1
#
#        leadbjet_pt  leadbjet_eta  ttbarMLR  largeRjet_pt_total  \
# 0          74.2067      1.155760     0.000             303.808
# 1         229.1180     -0.005455     0.000             319.519
# 2         354.8290      0.387903     0.000             379.502
# 3         111.3740     -1.131620     0.000             673.232
# 4         327.3410     -0.637407   836.840             749.172
# ...            ...           ...       ...                 ...
# 13983      63.3124     -2.219060     0.000             313.153
# 13984      79.7143      0.725713   858.712             403.237
# 13985     120.5620      2.143520     0.000             883.045
# 13986     173.8460      1.078890     0.000             336.483
# 13987      74.7254      2.058780     0.000             378.259
#
#        largeRjet_eta_total  largeRjet_phi_total  largeRjet_m_total  \
# 0                 0.716499             2.340630            105.440
# 1                -0.207688            -1.050650            124.417
# 2                 0.429905            -0.032258            101.729
# 3                -0.882717             2.047210            211.584
# 4                -1.939400            -0.584009            245.185
# ...                    ...                  ...                ...
# 13983            -1.469270            -0.309966            149.170
# 13984            -0.551284            -0.521822            163.453
# 13985             1.610580            -3.028970            283.641
# 13986             1.348570             1.986230            103.251
# 13987             1.617540             2.987240            169.910
#
#        largeRjet_tau32_total  weight
# 0                   0.701667       1
# 1                   0.658574       1
# 2                   0.705147       1
# 3                   1.222030       1
# 4                   1.182330       1
# ...                      ...     ...
# 13983               0.428863       1
# 13984               0.696539       1
# 13985               1.011700       1
# 13986               0.382302       1
# 13987               0.258449       1
#
# [13988 rows x 27 columns]

# %%
x_data = scaler.transform(data[train_features].values)
w_data = data["weight"].values

# %%
y_data_pred = model.predict(x_data)
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step

# %%
df_data = join_y_w(y_data_pred[:, 0], w_data[:])

# %%
bins = plt.hist(df_data['y_pred'], bins=30, histtype='step', color='blue', label='data', weights=df_data['scaleweights'])
plt.hist(df_test['y_pred'], bins=bins[1], histtype='step', color='red', label='test', weights=df_test['scaleweights'])
plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()

# %%
N, bins = np.histogram(df_data['y_pred'], bins=50, weights=df_data['scaleweights'])

B = np.histogram(df_test['y_pred'][y_test==0], bins=bins, weights=df_test['scaleweights'][y_test==0])[0]
S = np.histogram(df_test['y_pred'][y_test==1], bins=bins, weights=df_test['scaleweights'][y_test==1])[0]

# %%
# Plot N, S, B
plt.hist(bins[:-1], bins, weights=N, histtype='step', color='blue', label='data')
plt.hist(bins[:-1], bins, weights=B, histtype='step', color='green', label='bkg')
plt.hist(bins[:-1], bins, weights=S, histtype='step', color='red', label='sig')
plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()
plt.show()

# %%
model_spec = {'channels': [{'name': 'singlechannel',
              'samples': [
              {'name': 'signal','data': S.tolist(),
               'modifiers': [{'data': None, 'name': 'mu', 'type': 'normfactor'}]},
              {'name': 'bkg1','data': B.tolist(),
               'modifiers': []},
              ]
              }],
              "observations": [{ "name": "singlechannel", "data": N.tolist() }],
              "measurements": [{ "name": "Measurement", "config": {"poi": "mu", "parameters": []}}],
              "version": "1.0.0",
}

workspace = pyhf.Workspace(model_spec)
model = workspace.model()

print("## Model")
print(f"  channels: {model.config.channels}")
print(f"     nbins: {model.config.channel_nbins}")
print(f"   samples: {model.config.samples}")
print(f" modifiers: {model.config.modifiers}")
print(f"parameters: {model.config.parameters}")
print(f"par. order: {model.config.par_order}")

print("\n## Model parameters")
print(f'   default: {model.config.suggested_init()}')
print(f'    bounds: {model.config.suggested_bounds()}')

data = N.tolist() + model.config.auxdata

test_stat = "qtilde"
test_poi = 1.

# Vary mu values
poi_values = np.linspace(0.01, 5, 500)
obs_limit, exp_limits = pyhf.infer.intervals.upper_limits.upper_limit(data, model, poi_values, level=0.05)
print(f"\nObserved μ upper limit (obs): {obs_limit:.3f}, Expected μ upper limit {exp_limits[2]:.3f}")
# Out:
# ## Model
#   channels: ['singlechannel']
#      nbins: {'singlechannel': 50}
#    samples: ['bkg1', 'signal']
#  modifiers: [('mu', 'normfactor')]
# parameters: ['mu']
# par. order: ['mu']
#
# ## Model parameters
#    default: [1.0]
#     bounds: [(0, 10)]
#
# Observed μ upper limit (obs): 0.070, Expected μ upper limit 0.390
