# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from sklearn.metrics import roc_curve, roc_auc_score
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import Input
from keras.optimizers import AdamW
tf.random.set_seed(2)

import pyhf

# %%
# Create output directory
OUT_DIR = "./MachineLearning_optimized_best/"
os.makedirs(OUT_DIR, exist_ok=True)

# %%
# Load the dataframe with MC data and their labels (signal = 1, background = 0)
dataframe = pd.read_csv('dataframe.csv')

# %%
# Create train weights such that the sum of train weights for signal and background is equal (ratio bkg/sig = 1:1)
dataframe['train_weight'] = 1.
dataframe.loc[dataframe.query('label==1').index,'train_weight'] = (dataframe.loc[dataframe.query('label==1').index,'scaleweight']) / dataframe.loc[dataframe.query('label==1').index,'scaleweight'].sum()
dataframe.loc[dataframe.query('label==0').index,'train_weight'] = dataframe.loc[dataframe.query('label==0').index,'scaleweight'] / dataframe.loc[dataframe.query('label==0').index,'scaleweight'].sum()

sum_w_sig = dataframe.query('label==0')['train_weight'].sum()
sum_w_bkg = dataframe.query('label==1')['train_weight'].sum()
print(f'Sum of weights for training Signal {sum_w_sig:.3} and Background {sum_w_bkg:.3}')
# Out:
# Sum of weights for training Signal 1.0 and Background 1.0

# %%
# Define the features and weights to be used for training
train_features = ['etmiss', 'mtw', 'leadleptPt',
       'leadleptE', 'Q_leadlep',
       'leadTopLRjet_pt', 'leadTopLRjet_eta', 'leadTopLRjet_phi',
       'leadTopLRjet_m', 'leadTopLRjet_Tau32', 'n_jets', 'leadjet_pt',
        'n_bjets', 'leadbjet_pt', 'leadbjet_eta', 'ttbarMLR']
weights = ["scaleweight", "train_weight"]

# %%
# Split the dataframe into train, validation and test samples, and scale the features
x_train, x_val, y_train, y_val, w_train_full, w_val_full = train_test_split(dataframe[train_features].values, dataframe['label'].values, dataframe[weights].values, train_size = 1/3, random_state = 64)
x_val, x_test, y_val, y_test, w_val_full, w_test_full = train_test_split(x_val, y_val, w_val_full, test_size=1/2, random_state = 64)

scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)

# %%
# Verify that the ratio of signal to background in the training, validation and test sets is equal to 1
print(f"Ratio of signal to background in training set: {w_train_full[:, 1][y_train==1].sum() / w_train_full[:, 1][y_train==0].sum():.2f}")
print(f"Ratio of signal to background in validation set: {w_val_full[:, 1][y_val==1].sum() / w_val_full[:, 1][y_val==0].sum():.2f}")
print(f"Ratio of signal to background in test set: {w_test_full[:, 1][y_test==1].sum() / w_test_full[:, 1][y_test==0].sum():.2f}")
# Out:
# Ratio of signal to background in training set: 1.03
# Ratio of signal to background in validation set: 0.99
# Ratio of signal to background in test set: 0.99

# %%
# Separate the weights into scaleweights to use in the fit, and train weights to use in the training
def weight_separation(w):
    scaleweights = w[:, 0]
    train = w[:, 1]
    return scaleweights, train

"""
w_<set>_scale are the scaleweights to be used in the fit
w_<set> are the train weights to be used in the training
"""
w_train_scale, w_train = weight_separation(w_train_full)
w_val_scale, w_val = weight_separation(w_val_full)
w_test_scale, w_test = weight_separation(w_test_full)

# %%
"""
Define the model
----------------
The model has 5 layers:
- Input layer
- 3 Hidden layers
- Output layer

The input layer has the same number of nodes as the number of features in the training set.
The hidden layers have 75, 125, 125, 75 nodes respectively. The first hidden layer has dropout of 0.1.
The output layer has 1 node.

The activation functions for the hidden layers are 'softsign' and 'relu'.
The activation function for the output layer is 'sigmoid'.

The loss function is 'binary_crossentropy' and the optimizer is 'AdamW'.
The learning rate is 1e-3 and the weight decay is 1e-1.
"""

model = Sequential([Input(shape=(x_train.shape[1],))])

# Input and Hidden layers
model.add(Dense(75, activation='softsign'))
model.add(Dropout(0.1))
model.add(Dense(125, activation='softsign'))
model.add(Dense(125, activation='relu'))
model.add(Dense(75, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=AdamW(learning_rate=1e-3, weight_decay=1e-1), weighted_metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 75)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 75)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 125)            │         9,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 125)            │        15,750 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 75)             │         9,450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            76 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,051 (140.82 KB)
#  Trainable params: 36,051 (140.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(x_train, y_train, sample_weight=w_train, validation_data=(x_val, y_val, w_val), epochs=100, batch_size=1024, callbacks=[EarlyStopping(patience=2)])
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4832 - loss: 5.6208e-06 - val_accuracy: 0.5068 - val_loss: 5.4566e-06
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5114 - loss: 5.5745e-06 - val_accuracy: 0.5394 - val_loss: 5.4318e-06
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5448 - loss: 5.5427e-06 - val_accuracy: 0.5639 - val_loss: 5.4087e-06
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5748 - loss: 5.5114e-06 - val_accuracy: 0.5747 - val_loss: 5.3842e-06
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5906 - loss: 5.4731e-06 - val_accuracy: 0.5775 - val_loss: 5.3574e-06
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5898 - loss: 5.4441e-06 - val_accuracy: 0.5782 - val_loss: 5.3305e-06
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5959 - loss: 5.4100e-06 - val_accuracy: 0.5823 - val_loss: 5.3043e-06
# Epoch 8/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5928 - loss: 5.3739e-06 - val_accuracy: 0.5879 - val_loss: 5.2818e-06
# Epoch 9/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6000 - loss: 5.3462e-06 - val_accuracy: 0.5905 - val_loss: 5.2596e-06
# Epoch 10/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6049 - loss: 5.3166e-06 - val_accuracy: 0.5968 - val_loss: 5.2339e-06
# Epoch 11/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6093 - loss: 5.2838e-06 - val_accuracy: 0.6060 - val_loss: 5.2030e-06
# Epoch 12/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6213 - loss: 5.2362e-06 - val_accuracy: 0.6137 - val_loss: 5.1617e-06
# Epoch 13/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6358 - loss: 5.1705e-06 - val_accuracy: 0.6227 - val_loss: 5.1136e-06
# Epoch 14/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6461 - loss: 5.1199e-06 - val_accuracy: 0.6290 - val_loss: 5.0666e-06
# Epoch 15/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6571 - loss: 5.0617e-06 - val_accuracy: 0.6350 - val_loss: 5.0269e-06
# Epoch 16/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6661 - loss: 4.9999e-06 - val_accuracy: 0.6398 - val_loss: 4.9956e-06
# Epoch 17/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6716 - loss: 4.9654e-06 - val_accuracy: 0.6432 - val_loss: 4.9790e-06
# Epoch 18/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6680 - loss: 4.9355e-06 - val_accuracy: 0.6491 - val_loss: 4.9605e-06
# Epoch 19/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6750 - loss: 4.8984e-06 - val_accuracy: 0.6505 - val_loss: 4.9467e-06
# Epoch 20/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6798 - loss: 4.8877e-06 - val_accuracy: 0.6539 - val_loss: 4.9360e-06
# Epoch 21/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6765 - loss: 4.8785e-06 - val_accuracy: 0.6558 - val_loss: 4.9262e-06
# Epoch 22/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6751 - loss: 4.8777e-06 - val_accuracy: 0.6574 - val_loss: 4.9165e-06
# Epoch 23/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6788 - loss: 4.8463e-06 - val_accuracy: 0.6595 - val_loss: 4.9056e-06
# Epoch 24/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6829 - loss: 4.8411e-06 - val_accuracy: 0.6616 - val_loss: 4.8982e-06
# Epoch 25/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6873 - loss: 4.8232e-06 - val_accuracy: 0.6619 - val_loss: 4.8905e-06
# Epoch 26/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6897 - loss: 4.8188e-06 - val_accuracy: 0.6645 - val_loss: 4.8825e-06
# Epoch 27/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6898 - loss: 4.7832e-06 - val_accuracy: 0.6645 - val_loss: 4.8764e-06
# Epoch 28/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6868 - loss: 4.7920e-06 - val_accuracy: 0.6667 - val_loss: 4.8666e-06
# Epoch 29/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6929 - loss: 4.7744e-06 - val_accuracy: 0.6651 - val_loss: 4.8625e-06
# Epoch 30/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6925 - loss: 4.7653e-06 - val_accuracy: 0.6680 - val_loss: 4.8531e-06
# Epoch 31/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6947 - loss: 4.7411e-06 - val_accuracy: 0.6676 - val_loss: 4.8436e-06
# Epoch 32/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6948 - loss: 4.7215e-06 - val_accuracy: 0.6678 - val_loss: 4.8387e-06
# Epoch 33/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6951 - loss: 4.7332e-06 - val_accuracy: 0.6691 - val_loss: 4.8305e-06
# Epoch 34/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6961 - loss: 4.7045e-06 - val_accuracy: 0.6700 - val_loss: 4.8226e-06
# Epoch 35/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6999 - loss: 4.7046e-06 - val_accuracy: 0.6707 - val_loss: 4.8152e-06
# Epoch 36/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7029 - loss: 4.6805e-06 - val_accuracy: 0.6712 - val_loss: 4.8102e-06
# Epoch 37/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6993 - loss: 4.7009e-06 - val_accuracy: 0.6735 - val_loss: 4.8031e-06
# Epoch 38/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7046 - loss: 4.6770e-06 - val_accuracy: 0.6742 - val_loss: 4.7943e-06
# Epoch 39/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6970 - loss: 4.6788e-06 - val_accuracy: 0.6729 - val_loss: 4.7915e-06
# Epoch 40/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7039 - loss: 4.6550e-06 - val_accuracy: 0.6741 - val_loss: 4.7833e-06
# Epoch 41/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7031 - loss: 4.6516e-06 - val_accuracy: 0.6755 - val_loss: 4.7751e-06
# Epoch 42/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7097 - loss: 4.6320e-06 - val_accuracy: 0.6742 - val_loss: 4.7682e-06
# Epoch 43/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7047 - loss: 4.6299e-06 - val_accuracy: 0.6770 - val_loss: 4.7627e-06
# Epoch 44/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7067 - loss: 4.6291e-06 - val_accuracy: 0.6748 - val_loss: 4.7610e-06
# Epoch 45/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7087 - loss: 4.6187e-06 - val_accuracy: 0.6762 - val_loss: 4.7551e-06
# Epoch 46/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7045 - loss: 4.6278e-06 - val_accuracy: 0.6765 - val_loss: 4.7480e-06
# Epoch 47/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7077 - loss: 4.6079e-06 - val_accuracy: 0.6760 - val_loss: 4.7442e-06
# Epoch 48/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7010 - loss: 4.6136e-06 - val_accuracy: 0.6766 - val_loss: 4.7419e-06
# Epoch 49/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7089 - loss: 4.5870e-06 - val_accuracy: 0.6771 - val_loss: 4.7379e-06
# Epoch 50/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7035 - loss: 4.6009e-06 - val_accuracy: 0.6766 - val_loss: 4.7339e-06
# Epoch 51/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7065 - loss: 4.5944e-06 - val_accuracy: 0.6776 - val_loss: 4.7289e-06
# Epoch 52/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7123 - loss: 4.5771e-06 - val_accuracy: 0.6780 - val_loss: 4.7266e-06
# Epoch 53/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7081 - loss: 4.5965e-06 - val_accuracy: 0.6788 - val_loss: 4.7246e-06
# Epoch 54/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7072 - loss: 4.5686e-06 - val_accuracy: 0.6789 - val_loss: 4.7208e-06
# Epoch 55/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7118 - loss: 4.5632e-06 - val_accuracy: 0.6764 - val_loss: 4.7206e-06
# Epoch 56/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7095 - loss: 4.5372e-06 - val_accuracy: 0.6774 - val_loss: 4.7183e-06
# Epoch 57/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7110 - loss: 4.5587e-06 - val_accuracy: 0.6772 - val_loss: 4.7177e-06
# Epoch 58/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7030 - loss: 4.5861e-06 - val_accuracy: 0.6800 - val_loss: 4.7143e-06
# Epoch 59/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7101 - loss: 4.5507e-06 - val_accuracy: 0.6782 - val_loss: 4.7114e-06
# Epoch 60/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7168 - loss: 4.5462e-06 - val_accuracy: 0.6812 - val_loss: 4.7063e-06
# Epoch 61/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7166 - loss: 4.5480e-06 - val_accuracy: 0.6813 - val_loss: 4.7049e-06
# Epoch 62/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7143 - loss: 4.5446e-06 - val_accuracy: 0.6798 - val_loss: 4.7033e-06
# Epoch 63/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7137 - loss: 4.5205e-06 - val_accuracy: 0.6805 - val_loss: 4.7053e-06
# Epoch 64/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7113 - loss: 4.5503e-06 - val_accuracy: 0.6798 - val_loss: 4.6997e-06
# Epoch 65/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7090 - loss: 4.5447e-06 - val_accuracy: 0.6803 - val_loss: 4.6975e-06
# Epoch 66/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7148 - loss: 4.5363e-06 - val_accuracy: 0.6795 - val_loss: 4.6963e-06
# Epoch 67/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7103 - loss: 4.5230e-06 - val_accuracy: 0.6791 - val_loss: 4.6973e-06
# Epoch 68/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7117 - loss: 4.5274e-06 - val_accuracy: 0.6797 - val_loss: 4.6926e-06
# Epoch 69/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7129 - loss: 4.5445e-06 - val_accuracy: 0.6801 - val_loss: 4.6937e-06
# Epoch 70/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7105 - loss: 4.5263e-06 - val_accuracy: 0.6801 - val_loss: 4.6938e-06

# %%
# Plot the Loss per epoch 
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig(OUT_DIR + "loss.png")
plt.show()

# Plot the Accuracy per epoch
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(OUT_DIR + "accuracy.png")
plt.show()

# %%
# Compute the predictions for the training, validation and test sets
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)
y_test_pred = model.predict(x_test)
# Out:
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 239us/step
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 223us/step
# 2626/2626 ━━━━━━━━━━━━━━━━━━━━ 1s 218us/step

# %%
# Plot the histogram of the NN output for the test set
bin = plt.hist(y_test_pred[y_test==0], bins=50, density=True, histtype='step', color='blue', label='bkg test')
plt.hist(y_test_pred[y_test==1], bins=bin[1], density=True, histtype='step', color='red', label='sig test')

plt.xlabel('NN output')
plt.ylabel('Density')
plt.legend()
plt.savefig(OUT_DIR + "NN_test_output.png")
plt.show()

# %%
# Plot the histogram of the NN output for the training and validation sets
bins = plt.hist(y_train_pred[y_train==1], bins=50, density=True, histtype='step', color='blue', label='sig train')
plt.hist(y_val_pred[y_val==1], bins=bins[1], density=True, histtype='step', color='red', label='sig val')
bins = plt.hist(y_train_pred[y_train==0], bins=bins[1], density=True, histtype='step', color='green', label='bkg train')
plt.hist(y_val_pred[y_val==0], bins=bins[1], density=True, histtype='step', color='orange', label='bkg val')

plt.xlabel('NN output')
plt.legend()
plt.savefig(OUT_DIR + "NN_train_val_output.png")
plt.show()

# %%
# ROC curve for the test set
fpr, tpr, thresholds = roc_curve(y_test, y_test_pred)
auc = roc_auc_score(y_test, y_test_pred)
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='black')
plt.title('ROC curve')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend()
plt.savefig(OUT_DIR + "ROC_curve.png")
plt.show()

# %%
# Create dataframe of the predictions and its respective scaleweights
def join_y_w(y, w):
    df = pd.DataFrame({'y_pred': y, 'scaleweights': w})
    return df

df_train = join_y_w(y_train_pred[:, 0], w_train_scale[:])
df_val = join_y_w(y_val_pred[:, 0], w_val_scale[:])
df_test = join_y_w(y_test_pred[:, 0], w_test_scale[:]*3) # Multiply by 3 to account for the 1/3 of the test set

# %%
# Import the measured data
data = pd.read_csv('Output_ZPrimeBoostedAnalysis/data.csv', delimiter= " ")
data
# Out:
#          etmiss       mtw  leadleptPt  leadleptEta  leadleptE  leadleptPhi  \
# 0      140.8590  112.6010    173.3020    -0.719597   220.1410    -0.629445
# 1      101.1240   12.9607     84.2450     0.521832    95.9780     1.694020
# 2       93.8502  145.9590     69.5917    -0.571767    81.2804     2.401100
# 3       79.1584   78.5076     39.4455     0.320825    41.4930     1.189650
# 4       49.9677  119.0770     78.1793    -1.261530   149.0890    -0.060379
# ...         ...       ...         ...          ...        ...          ...
# 13983   51.2650   36.3069     32.4356    -1.826030   103.3120     2.875370
# 13984  177.2230   98.1917    226.8500     0.625051   272.6260     2.951550
# 13985  379.7260   76.7778     38.0448     0.559037    44.1463    -2.853520
# 13986   76.5990   32.0798     68.3700    -0.439462    75.0790    -0.758893
# 13987  171.2450   48.1760     46.2895     1.833340   148.4640    -0.367425
#
#        Q_leadlep  leadleptID  n_TopLRjets  leadTopLRjet_pt  ...  n_bjets  \
# 0              1          11            1          303.808  ...        2
# 1              1          13            1          319.519  ...        1
# 2              1          11            1          379.502  ...        1
# 3             -1          11            1          364.358  ...        2
# 4              1          11            1          381.640  ...        4
# ...          ...         ...          ...              ...  ...      ...
# 13983          1          11            1          313.153  ...        1
# 13984         -1          13            1          403.237  ...        1
# 13985          1          13            1          618.111  ...        2
# 13986          1          11            1          336.483  ...        1
# 13987         -1          13            1          378.259  ...        1
#
#        leadbjet_pt  leadbjet_eta  ttbarMLR  largeRjet_pt_total  \
# 0          74.2067      1.155760     0.000             303.808
# 1         229.1180     -0.005455     0.000             319.519
# 2         354.8290      0.387903     0.000             379.502
# 3         111.3740     -1.131620     0.000             673.232
# 4         327.3410     -0.637407   836.840             749.172
# ...            ...           ...       ...                 ...
# 13983      63.3124     -2.219060     0.000             313.153
# 13984      79.7143      0.725713   858.712             403.237
# 13985     120.5620      2.143520     0.000             883.045
# 13986     173.8460      1.078890     0.000             336.483
# 13987      74.7254      2.058780     0.000             378.259
#
#        largeRjet_eta_total  largeRjet_phi_total  largeRjet_m_total  \
# 0                 0.716499             2.340630            105.440
# 1                -0.207688            -1.050650            124.417
# 2                 0.429905            -0.032258            101.729
# 3                -0.882717             2.047210            211.584
# 4                -1.939400            -0.584009            245.185
# ...                    ...                  ...                ...
# 13983            -1.469270            -0.309966            149.170
# 13984            -0.551284            -0.521822            163.453
# 13985             1.610580            -3.028970            283.641
# 13986             1.348570             1.986230            103.251
# 13987             1.617540             2.987240            169.910
#
#        largeRjet_tau32_total  weight
# 0                   0.701667       1
# 1                   0.658574       1
# 2                   0.705147       1
# 3                   1.222030       1
# 4                   1.182330       1
# ...                      ...     ...
# 13983               0.428863       1
# 13984               0.696539       1
# 13985               1.011700       1
# 13986               0.382302       1
# 13987               0.258449       1
#
# [13988 rows x 27 columns]

# %%
# Apply the same scaling to the measured data and get the weights
x_data = scaler.transform(data[train_features].values)
w_data = data["weight"].values

# Compute the predictions for the measured data
y_data_pred = model.predict(x_data)

# Create dataframe of the predictions and its respective weights
df_data = join_y_w(y_data_pred[:, 0], w_data[:])
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step

# %%
# Plot the histogram of the NN output for the measured data and the test set
bins = plt.hist(df_data['y_pred'], bins=20, histtype='step', color='blue', label='Measured Data', weights=df_data['scaleweights'])
plt.hist(df_test['y_pred'], bins=bins[1], histtype='step', color='red', label='Test Set Output', weights=df_test['scaleweights'])
plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()
plt.savefig(OUT_DIR + "NN_data_test_output.png")
plt.show()

# %%
# Create the distribution of the measured data and the test set signal and background NN output
N, bins = np.histogram(df_data['y_pred'], bins=20, weights=df_data['scaleweights'])

B = np.histogram(df_test['y_pred'][y_test==0], bins=bins, weights=df_test['scaleweights'][y_test==0])[0]
S = np.histogram(df_test['y_pred'][y_test==1], bins=bins, weights=df_test['scaleweights'][y_test==1])[0]

# %%
# Select the bins where there is less signal (the background is more pure) to use in the fit to discover the background normalization factor epsilon
N2 = N[:9]
B2 = B[:9]
S2 = S[:9]

#plot
plt.hist(bins[:9], bins, weights=N2, histtype='step', color='blue', label='data')
plt.hist(bins[:9], bins, weights=B2, histtype='step', color='red', label='bkg')
plt.hist(bins[:9], bins, weights=S2, histtype='step', color='green', label='sig')
plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()
plt.savefig(OUT_DIR + "NN_bkg_cut.png")
plt.show()

# %%
# Save the NN output and its respective type and weights to a csv file (measured data, test set, train set, validation set)
dataframe_to_save1 = pd.DataFrame({'Type': 'Observed', 'NN output': df_data['y_pred'], "weights": df_data['scaleweights']})
dataframe_to_save2 = pd.DataFrame({'Type': 'Test Bkg', 'NN output': df_test['y_pred'][y_test==0], "weights": (df_test['scaleweights'][y_test==0])/3})
dataframe_to_save3 = pd.DataFrame({'Type': 'Test Sig', 'NN output': df_test['y_pred'][y_test==1], "weights": (df_test['scaleweights'][y_test==1])/3})
dataframe_to_save4 = pd.DataFrame({'Type': 'Train Bkg', 'NN output': df_train['y_pred'][y_train==0], "weights": (df_test['scaleweights'][y_train==0])})
dataframe_to_save5 = pd.DataFrame({'Type': 'Train Sig', 'NN output': df_train['y_pred'][y_train==1], "weights": (df_test['scaleweights'][y_train==1])})
dataframe_to_save6 = pd.DataFrame({'Type': 'Val Bkg', 'NN output': df_val['y_pred'][y_val==0], "weights": (df_test['scaleweights'][y_val==0])})
dataframe_to_save7 = pd.DataFrame({'Type': 'Val Sig', 'NN output': df_val['y_pred'][y_val==1], "weights": (df_test['scaleweights'][y_val==1])})

dataframe_to_save = pd.concat([dataframe_to_save1, dataframe_to_save2, dataframe_to_save3, dataframe_to_save4, dataframe_to_save5, dataframe_to_save6, dataframe_to_save7])
dataframe_to_save.to_csv(OUT_DIR + "NN_output.csv", index=False)

# %%
dataframe_to_save
# Out:
#            Type  NN output   weights
# 0      Observed   0.349849  1.000000
# 1      Observed   0.174053  1.000000
# 2      Observed   0.210773  1.000000
# 3      Observed   0.358695  1.000000
# 4      Observed   0.538794  1.000000
# ...         ...        ...       ...
# 83774   Val Sig   0.363104  0.193072
# 83786   Val Sig   0.590732  0.443364
# 83838   Val Sig   0.572571  0.011951
# 83924   Val Sig   0.595733  0.259007
# 83941   Val Sig   0.340200  0.222571
#
# [266084 rows x 3 columns]

# %%
# Plot the distribution of the measured data, the signal and background
plt.hist(bins[:-1], bins, weights=N, histtype='step', color='blue', label='data')
plt.hist(bins[:-1], bins, weights=B, histtype='step', color='green', label='bkg')
plt.hist(bins[:-1], bins, weights=S, histtype='step', color='red', label='sig')

plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()
plt.savefig(OUT_DIR + "NN_NSB.png")
plt.show()

# %%
# Fit the model to the data to obtain the background normalization factor epsilon, using the bins with less signal

model_spec_discovery = {'channels': [{'name': 'singlechannel',
              'samples': [
              {'name': 'signal','data': S2.tolist(),
               'modifiers': []},
              {'name': 'bkg1','data': B2.tolist(),
               'modifiers': [{'data': None, 'name': 'epsilon', 'type': 'normfactor'}]},
              ]
              }],
              "observations": [{ "name": "singlechannel", "data": N2.tolist() }],
              "measurements": [{ "name": "Measurement", "config": {"poi": 'epsilon', "parameters": []}}],

              "version": "1.0.0",
}

workspace_discovery = pyhf.Workspace(model_spec_discovery)
model_discovery = workspace_discovery.model()

print("## Model")
print(f"  channels: {model_discovery.config.channels}")
print(f"     nbins: {model_discovery.config.channel_nbins}")
print(f"   samples: {model_discovery.config.samples}")
print(f" modifiers: {model_discovery.config.modifiers}")
print(f"parameters: {model_discovery.config.parameters}")
print(f"par. order: {model_discovery.config.par_order}")

print("\n## Model parameters")
print(f'   default: {model_discovery.config.suggested_init()}')
print(f'    bounds: {model_discovery.config.suggested_bounds()}')

data = N2.tolist() + model_discovery.config.auxdata

test_stat = "q0"
test_poi = 0.

best_pars = pyhf.infer.mle.fit(data=data, pdf=model_discovery)
print("\nBest fit parameters:")
print(f"  epsilon: {best_pars[0]:.2e}")

epsilon = best_pars[0]
# Out:
# ## Model
#   channels: ['singlechannel']
#      nbins: {'singlechannel': 9}
#    samples: ['bkg1', 'signal']
#  modifiers: [('epsilon', 'normfactor')]
# parameters: ['epsilon']
# par. order: ['epsilon']
#
# ## Model parameters
#    default: [1.0]
#     bounds: [(0, 10)]
#
# Best fit parameters:
#   epsilon: 9.11e-01

# %%
# Plot the distribution of the measured data, the signal and normalized background
B3 = epsilon * B

plt.hist(bins[:-1], bins, weights=N, histtype='step', color='blue', label='measured data')
plt.hist(bins[:-1], bins, weights=B3, histtype='step', color='green', label=r'bkg * $\epsilon$ = bkg * %.2e' % epsilon)
plt.hist(bins[:-1], bins, weights=S, histtype='step', color='red', label='sig')
plt.xlabel('NN output')
plt.ylabel('Events')
plt.legend()
plt.savefig(OUT_DIR + "NN_NSB_discovery.png")
plt.show()

# %%
# Exclusion Fit to obtain the upper limit on the signal strength
model_spec = {'channels': [{'name': 'singlechannel',
              'samples': [
              {'name': 'signal','data': S.tolist(),
               'modifiers': [{'data': None, 'name': 'mu', 'type': 'normfactor'}]},
              {'name': 'bkg1','data': B.tolist(),
               'modifiers': []},
              ]
              }],
              "observations": [{ "name": "singlechannel", "data": N.tolist() }],
              "measurements": [{ "name": "Measurement", "config": {"poi": 'mu', "parameters": []}}],

              "version": "1.0.0",
}

workspace = pyhf.Workspace(model_spec)
model = workspace.model()

print("## Model")
print(f"  channels: {model.config.channels}")
print(f"     nbins: {model.config.channel_nbins}")
print(f"   samples: {model.config.samples}")
print(f" modifiers: {model.config.modifiers}")
print(f"parameters: {model.config.parameters}")
print(f"par. order: {model.config.par_order}")

print("\n## Model parameters")
print(f'   default: {model.config.suggested_init()}')
print(f'    bounds: {model.config.suggested_bounds()}')

data = N.tolist() + model.config.auxdata

test_stat = "qtilde"
test_poi = 1.

# Vary mu values
poi_values = np.linspace(0.01, 5, 500)
obs_limit, exp_limits, (scan, results) = pyhf.infer.intervals.upper_limits.upper_limit(data, model, poi_values, level=0.05, return_results=True)
print(f"\nObserved μ upper limit (obs): {obs_limit:.3f}, Expected μ upper limit {exp_limits[2]:.3f}")

# CLs_obs, CLs_exp = pyhf.infer.hypotest(test_poi, data, model, test_stat=test_stat, return_expected=True)
# print(f"Observed CL_s: {CLs_obs}, Expected CL_s: {CLs_exp} ")
# Out:
# ## Model
#   channels: ['singlechannel']
#      nbins: {'singlechannel': 20}
#    samples: ['bkg1', 'signal']
#  modifiers: [('mu', 'normfactor')]
# parameters: ['mu']
# par. order: ['mu']
#
# ## Model parameters
#    default: [1.0]
#     bounds: [(0, 10)]
#
# Observed μ upper limit (obs): 0.085, Expected μ upper limit 0.395

# %%
# Exclusion Fit to obtain the upper limit on the signal strength
model_spec_norm = {'channels': [{'name': 'singlechannel',
              'samples': [
              {'name': 'signal','data': S.tolist(),
               'modifiers': [{'data': None, 'name': 'mu', 'type': 'normfactor'}]},
              {'name': 'bkg1','data': B3.tolist(),
               'modifiers': []},
              ]
              }],
              "observations": [{ "name": "singlechannel", "data": N.tolist() }],
              "measurements": [{ "name": "Measurement", "config": {"poi": 'mu', "parameters": []}}],

              "version": "1.0.0",
}

workspace = pyhf.Workspace(model_spec_norm)
model = workspace.model()

print("## Model")
print(f"  channels: {model.config.channels}")
print(f"     nbins: {model.config.channel_nbins}")
print(f"   samples: {model.config.samples}")
print(f" modifiers: {model.config.modifiers}")
print(f"parameters: {model.config.parameters}")
print(f"par. order: {model.config.par_order}")

print("\n## Model parameters")
print(f'   default: {model.config.suggested_init()}')
print(f'    bounds: {model.config.suggested_bounds()}')

data = N.tolist() + model.config.auxdata

test_stat = "qtilde"
test_poi = 1.

# Vary mu values
poi_values = np.linspace(0.01, 5, 500)
obs_limit_norm, exp_limits_norm, (scan, results) = pyhf.infer.intervals.upper_limits.upper_limit(data, model, poi_values, level=0.05, return_results=True)
print(f"\nObserved μ upper limit (obs): {obs_limit_norm:.3f}, Expected μ upper limit {exp_limits_norm[2]:.3f}")
# Out:
# ## Model
#   channels: ['singlechannel']
#      nbins: {'singlechannel': 20}
#    samples: ['bkg1', 'signal']
#  modifiers: [('mu', 'normfactor')]
# parameters: ['mu']
# par. order: ['mu']
#
# ## Model parameters
#    default: [1.0]
#     bounds: [(0, 10)]
#
# Observed μ upper limit (obs): 0.495, Expected μ upper limit 0.377

# %%
# save result to txt
with open(OUT_DIR + "results.txt", "w") as f:
    f.write(f"Value for epsilon (background normalization factor): {epsilon}\n")
    f.write(f"Observed μ upper limit (obs) with epsilon: {obs_limit_norm}\n")
    f.write(f"Expected μ upper limit (exp) with epsilon: {exp_limits_norm[2]}\n\n\n")
    f.write(f"Observed μ upper limit (obs): {obs_limit}\n")
    f.write(f"Expected μ upper limit (exp): {exp_limits[2]}\n")
