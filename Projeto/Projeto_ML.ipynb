# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('dataframe.csv')
data
# Out:
#         Unnamed: 0          ID    etmiss       mtw  leadleptPt  leadleptEta  \
# 0                0      signal  284.0070   51.4513    158.2950     0.125750
# 1                1      signal  194.7950  100.9790     58.2204    -0.676782
# 2                2      signal  248.7820   68.8350     44.5272    -0.311100
# 3                3      signal   98.7296   19.8922    261.8510     0.385745
# 4                4      signal  248.7050   32.9140    149.7410     1.617440
# ...            ...         ...       ...       ...         ...          ...
# 252091      252091  lepton_bkg  232.9160   16.1447     53.0237    -0.827826
# 252092      252092  lepton_bkg  234.3410   68.3447     43.5060     0.293652
# 252093      252093  lepton_bkg  120.0420   98.2329     38.0663     1.822840
# 252094      252094  lepton_bkg  143.3440  155.8760     70.7158    -0.114848
# 252095      252095  lepton_bkg  106.8330  131.4680    248.7940     1.507020
#
#         leadleptE  leadleptPhi  Q_leadlep  leadleptID  ...  ttbarMLR  \
# 0        159.5480     0.246570         -1          13  ...   616.923
# 1         72.0706    -0.338934          1          11  ...   571.721
# 2         46.6994     3.066820         -1          11  ...   536.674
# 3        281.5750    -2.184720          1          13  ...   921.435
# 4        392.2160    -1.361590          1          11  ...   853.772
# ...           ...          ...        ...         ...  ...       ...
# 252091    72.2537    -2.364720          1          11  ...     0.000
# 252092    45.3953    -2.418000         -1          11  ...   697.808
# 252093   120.8800     2.297760          1          13  ...     0.000
# 252094    71.1828    -2.978210          1          13  ...     0.000
# 252095   588.9990     1.059860         -1          13  ...     0.000
#
#         largeRjet_pt_total  largeRjet_eta_total  largeRjet_phi_total  \
# 0                  434.907             0.003795            -3.105850
# 1                  373.238             0.031308            -2.606120
# 2                  403.840             0.685499             0.631162
# 3                  472.371             0.048611             0.576137
# 4                  420.366             0.136872             1.328520
# ...                    ...                  ...                  ...
# 252091             327.821             1.144510             0.510144
# 252092             344.195             1.116320             1.200730
# 252093             713.254             0.580453             0.511460
# 252094             836.475            -0.616361             2.270880
# 252095             321.528             0.804654            -1.978370
#
#         largeRjet_m_total  largeRjet_tau32_total    weight     scale  label  \
# 0                 172.235               0.263504  0.000000  0.056722      1
# 1                 158.346               0.462140  0.000000  0.056722      1
# 2                 175.933               0.290648  0.000000  0.056722      1
# 3                 223.665               0.428973  0.000000  0.056722      1
# 4                 121.342               0.496269  0.002304  0.056722      1
# ...                   ...                    ...       ...       ...    ...
# 252091            123.086               0.670010  0.167915  0.018804      0
# 252092            115.454               0.668324  0.141649  0.018804      0
# 252093            119.566               0.691067  0.209875  0.018804      0
# 252094            242.974               1.260570  0.088000  0.018804      0
# 252095            158.254               0.446668  0.123988  0.018804      0
#
#         scaleweight
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000131
# ...             ...
# 252091     0.003157
# 252092     0.002664
# 252093     0.003946
# 252094     0.001655
# 252095     0.002331
#
# [252096 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'etmiss', 'mtw', 'leadleptPt', 'leadleptEta',
#        'leadleptE', 'leadleptPhi', 'Q_leadlep', 'leadleptID', 'n_TopLRjets',
#        'leadTopLRjet_pt', 'leadTopLRjet_eta', 'leadTopLRjet_phi',
#        'leadTopLRjet_m', 'leadTopLRjet_Tau32', 'n_jets', 'leadjet_pt',
#        'leadjet_eta', 'n_bjets', 'leadbjet_pt', 'leadbjet_eta', 'ttbarMLR',
#        'largeRjet_pt_total', 'largeRjet_eta_total', 'largeRjet_phi_total',
#        'largeRjet_m_total', 'largeRjet_tau32_total', 'weight', 'scale',
#        'label', 'scaleweight'],
#       dtype='object')

# %%
training_features = ['etmiss', 'mtw', 'leadleptPt', 'leadleptEta',
       'leadleptE', 'leadleptPhi', 'n_TopLRjets',
       'leadTopLRjet_pt', 'leadTopLRjet_eta', 'leadTopLRjet_phi',
       'leadTopLRjet_m', 'leadTopLRjet_Tau32', 'n_jets', 'leadjet_pt',
       'leadjet_eta', 'n_bjets', 'leadbjet_pt', 'leadbjet_eta', 'ttbarMLR']
label = "label"

# %%
scaler = StandardScaler()
data[training_features] = scaler.fit_transform(data[training_features].values)

X = scaler.transform(data[training_features].values)
y = data[label].values
w = data['scaleweight'].values

x_train, x_test, y_train, y_test, w_train, w_test = train_test_split(X, y, w, test_size=0.2, random_state=42)

# %%
print(f'Train sample x {len(x_train)} events (y {len(y_train)} events)')
print(f'Test  sample x {len(x_test)} events (y {len(y_test)} events)')
# Out:
# Train sample x 201676 events (y 201676 events)
# Test  sample x 50420 events (y 50420 events)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import tensorflow as tf

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras import Input
from tensorflow.keras.optimizers import Adam
tf.random.set_seed(2)

# %%
# your answer
print(x_train.shape)
model = Sequential([Input(shape=(x_train.shape[1],))])

# Input and Hidden layers

model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), weighted_metrics=['accuracy'])
model.summary()

history = model.fit(x_train, y_train, sample_weight=w_train, validation_data=(x_test, y_test, w_test), epochs=100, batch_size=1024)#, callbacks=[EarlyStopping(patience=4)])
# Out:
# (201676, 19)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,649 (295.50 KB)
#  Trainable params: 75,649 (295.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9705 - loss: 0.0095 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 2/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0077 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 3/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 4/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 5/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 6/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 7/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 8/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 9/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 10/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 11/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 12/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 13/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 14/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 15/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 16/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0076 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 17/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 18/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 19/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 20/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 21/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 22/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 23/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 24/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 25/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 26/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 27/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0075 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 28/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0073
# Epoch 29/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 30/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 31/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 32/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 33/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 34/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 35/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0074 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 36/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0073 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 37/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0073 - val_accuracy: 0.9737 - val_loss: 0.0074
# Epoch 38/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0073 - val_accuracy: 0.9737 - val_loss: 0.0075
# Epoch 39/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0073 - val_accuracy: 0.9737 - val_loss: 0.0075
# Epoch 40/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0073 - val_accuracy: 0.9736 - val_loss: 0.0075
# Epoch 41/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0073 - val_accuracy: 0.9737 - val_loss: 0.0075
# Epoch 42/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.0075
# Epoch 43/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.0076
# Epoch 44/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.0076
# Epoch 45/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0072 - val_accuracy: 0.9735 - val_loss: 0.0076
# Epoch 46/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0072 - val_accuracy: 0.9735 - val_loss: 0.0076
# Epoch 47/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0072 - val_accuracy: 0.9734 - val_loss: 0.0077
# Epoch 48/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9722 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.0077
# Epoch 49/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0071 - val_accuracy: 0.9734 - val_loss: 0.0077
# Epoch 50/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0071 - val_accuracy: 0.9735 - val_loss: 0.0077
# Epoch 51/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0071 - val_accuracy: 0.9734 - val_loss: 0.0078
# Epoch 52/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9724 - loss: 0.0070 - val_accuracy: 0.9737 - val_loss: 0.0078
# Epoch 53/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9724 - loss: 0.0070 - val_accuracy: 0.9736 - val_loss: 0.0079
# Epoch 54/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0070 - val_accuracy: 0.9737 - val_loss: 0.0079
# Epoch 55/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0070 - val_accuracy: 0.9736 - val_loss: 0.0080
# Epoch 56/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0069 - val_accuracy: 0.9732 - val_loss: 0.0081
# Epoch 57/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9724 - loss: 0.0069 - val_accuracy: 0.9733 - val_loss: 0.0080
# Epoch 58/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0069 - val_accuracy: 0.9734 - val_loss: 0.0081
# Epoch 59/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0069 - val_accuracy: 0.9734 - val_loss: 0.0081
# Epoch 60/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0068 - val_accuracy: 0.9731 - val_loss: 0.0082
# Epoch 61/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0068 - val_accuracy: 0.9730 - val_loss: 0.0083
# Epoch 62/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.0068 - val_accuracy: 0.9731 - val_loss: 0.0083
# Epoch 63/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.0068 - val_accuracy: 0.9729 - val_loss: 0.0084
# Epoch 64/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.0068 - val_accuracy: 0.9730 - val_loss: 0.0084
# Epoch 65/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.0068 - val_accuracy: 0.9731 - val_loss: 0.0084
# Epoch 66/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9727 - loss: 0.0067 - val_accuracy: 0.9729 - val_loss: 0.0084
# Epoch 67/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9727 - loss: 0.0067 - val_accuracy: 0.9731 - val_loss: 0.0084
# Epoch 68/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0067 - val_accuracy: 0.9732 - val_loss: 0.0084
# Epoch 69/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9727 - loss: 0.0067 - val_accuracy: 0.9732 - val_loss: 0.0084
# Epoch 70/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9727 - loss: 0.0067 - val_accuracy: 0.9729 - val_loss: 0.0084
# Epoch 71/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0067 - val_accuracy: 0.9727 - val_loss: 0.0083
# Epoch 72/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0067 - val_accuracy: 0.9729 - val_loss: 0.0083
# Epoch 73/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0066 - val_accuracy: 0.9728 - val_loss: 0.0083
# Epoch 74/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9729 - loss: 0.0066 - val_accuracy: 0.9730 - val_loss: 0.0084
# Epoch 75/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9729 - loss: 0.0066 - val_accuracy: 0.9729 - val_loss: 0.0084
# Epoch 76/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0065 - val_accuracy: 0.9729 - val_loss: 0.0084
# Epoch 77/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9729 - loss: 0.0065 - val_accuracy: 0.9728 - val_loss: 0.0085
# Epoch 78/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0064 - val_accuracy: 0.9725 - val_loss: 0.0086
# Epoch 79/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0065 - val_accuracy: 0.9721 - val_loss: 0.0088
# Epoch 80/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9731 - loss: 0.0064 - val_accuracy: 0.9723 - val_loss: 0.0087
# Epoch 81/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9733 - loss: 0.0063 - val_accuracy: 0.9721 - val_loss: 0.0088
# Epoch 82/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9732 - loss: 0.0064 - val_accuracy: 0.9721 - val_loss: 0.0087
# Epoch 83/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0063 - val_accuracy: 0.9722 - val_loss: 0.0087
# Epoch 84/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9731 - loss: 0.0063 - val_accuracy: 0.9718 - val_loss: 0.0088
# Epoch 85/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9734 - loss: 0.0062 - val_accuracy: 0.9720 - val_loss: 0.0088
# Epoch 86/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0062 - val_accuracy: 0.9721 - val_loss: 0.0089
# Epoch 87/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0062 - val_accuracy: 0.9721 - val_loss: 0.0089
# Epoch 88/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0062 - val_accuracy: 0.9721 - val_loss: 0.0089
# Epoch 89/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9733 - loss: 0.0062 - val_accuracy: 0.9716 - val_loss: 0.0089
# Epoch 90/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9732 - loss: 0.0062 - val_accuracy: 0.9726 - val_loss: 0.0089
# Epoch 91/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0062 - val_accuracy: 0.9723 - val_loss: 0.0090
# Epoch 92/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0061 - val_accuracy: 0.9716 - val_loss: 0.0091
# Epoch 93/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0061 - val_accuracy: 0.9714 - val_loss: 0.0091
# Epoch 94/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0060 - val_accuracy: 0.9709 - val_loss: 0.0092
# Epoch 95/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9738 - loss: 0.0060 - val_accuracy: 0.9710 - val_loss: 0.0094
# Epoch 96/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0060 - val_accuracy: 0.9696 - val_loss: 0.0094
# Epoch 97/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9741 - loss: 0.0059 - val_accuracy: 0.9700 - val_loss: 0.0095
# Epoch 98/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9737 - loss: 0.0059 - val_accuracy: 0.9703 - val_loss: 0.0095
# Epoch 99/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9734 - loss: 0.0060 - val_accuracy: 0.9691 - val_loss: 0.0095
# Epoch 100/100
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0060 - val_accuracy: 0.9697 - val_loss: 0.0094

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
